# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleaned_data/df_odds.csv')
# Out:
# /tmp/ipykernel_70169/3904490113.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('cleaned_data/df_odds.csv')
